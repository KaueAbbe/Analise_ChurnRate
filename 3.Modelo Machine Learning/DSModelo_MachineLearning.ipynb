# %% [markdown]
# <a href="https://colab.research.google.com/github/KaueAbbe/Challenge_Data_Science1_Alura/blob/main/Semana%203/DSModelo_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color = 'red' size = 10 > Modelo de Machine Learning </font>
# #### **Autor:** Kaue Hermann Abbehausen
# #### **Linkedin:** https://www.linkedin.com/in/kaue-abbehausen-5b1922165/
# ## <font color = 'green'> Contextualizando</font>
# Eu atuo como cientista de dados pela operadora de telecomunicações Alura Voz. Na reunião inicial com as pessoas responsáveis pela área de vendas da empresa, foi explicada a importância de se reduzir a Taxa de Evasão de Clientes, conhecido como **Churn Rate**. Basicamente, o **Churn Rate indica o quanto a empresa perdeu de receita ou clientes em um período de tempo.**
#
# Eu sugeri, como passo inicial, a identificação de clientes que teriam uma maior chance de deixar a empresa. Para isso, expliquei que é interessante investigar algumas características de clientes ou dos planos de clientes para tentar CLASSIFICAR estas pessoas como potenciais candidatas a deixar a empresa ou não.
#
# Assim, solicitei o conjunto de dados para começar a explorar, tratar e modelar a partir de agora. Em seguida, o foco será na otimização de cada um dos modelos com a finalidade de obter o melhor resultado para a tomada de decisão da Alura Voz.
#
# * **Os dados foram retirados de uma API e podem ser encontrado no link abaixo:**
#
# https://github.com/sthemonica/alura-voz/blob/main/Dados/Telco-Customer-Churn.json
#
# * **Os dados foram tratados no arquivo Semana 1 e são encontrados no link abaixo:**
#
# https://github.com/KaueAbbe/Challenge_Data_Science1_Alura
# * Versão Raw
#
# https://raw.githubusercontent.com/KaueAbbe/Challenge_Data_Science1_Alura/main/Telco-Customer-Churn-Corrigido.json
#
#
# * **A análise exploratório dos dados foi feita na semana 2.E agora é o momento de criar um modelo de machine learning em que é possível prever quais os clientes que podem vir a evadir da empresa AluraVoz**

# %% [markdown]
# ## **Resultados da Análise exploratória**
#
# Durante a análise exploratória foram encontrados variáveis que apresentam diferença entre os grupos que evadiram e que não evadiram. Para as variáveis do tipo qualitativas (categóricas) temos:
#
# * Idoso,
#  Parceiro,
#  Dependencia,
#  Tipo_contrato,
#  Fatura_online,
#  Metodo_pagamento,
#  Servico_internet,
#  Assinatura_tv,
#  Assinatura_filme
#
#  Desta lista de variáveis categóricas apenas Idoso, Parceiro, dependencia, Fatura_online, servico_internet, assinatura_tv e assinatura_filme são de duas categorias (sim ou não).

# %%
import pandas as pd
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier
import numpy as np

# %%
dados = pd.read_json('https://raw.githubusercontent.com/KaueAbbe/Challenge_Data_Science1_Alura/main/Telco-Customer-Churn-Corrigido.json')
dados[['Evadiu','Idoso',
 'Parceiro',
 'Dependencia',
 'Tipo_contrato',
 'Fatura_online',
 'Metodo_pagamento',
 'Servico_internet',
 'Assinatura_tv',
 'Assinatura_filme']].head(10)
# Out:
#   Evadiu Idoso Parceiro Dependencia Tipo_contrato Fatura_online  \
# 0    Nao   Nao      Sim         Sim         Anual           Sim
# 1    Nao   Nao      Nao         Nao     Mes a Mes           Nao
# 2    Sim   Nao      Nao         Nao     Mes a Mes           Sim
# 3    Sim   Sim      Sim         Nao     Mes a Mes           Sim
# 4    Sim   Sim      Sim         Nao     Mes a Mes           Sim
# 5    Nao   Nao      Nao         Sim     Mes a Mes           Sim
# 6    Nao   Sim      Sim         Nao       Bianual           Sim
# 7    Nao   Nao      Sim         Nao       Bianual           Sim
# 8    Nao   Sim      Nao         Nao     Mes a Mes           Sim
# 9    Nao   Nao      Sim         Sim       Bianual           Sim
#
#                       Metodo_pagamento Servico_internet Assinatura_tv  \
# 0                     Cheque por Email              DSL           Sim
# 1                     Cheque por Email              DSL           Nao
# 2                    Cheque Eletronico     Fibra optica           Nao
# 3                    Cheque Eletronico     Fibra optica           Sim
# 4                     Cheque por Email     Fibra optica           Sim
# 5          Cartao Credito (automatico)              DSL           Sim
# 6  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 7          Cartao Credito (automatico)     Fibra optica           Nao
# 8                    Cheque Eletronico              DSL           Nao
# 9                     Cheque por Email              DSL           Sim
#
#   Assinatura_filme
# 0              Nao
# 1              Sim
# 2              Nao
# 3              Sim
# 4              Nao
# 5              Sim
# 6              Sim
# 7              Nao
# 8              Nao
# 9              Sim

# %%
dados.groupby('Evadiu').count()['Genero']
# Out:
# Evadiu
# Nao    5174
# Sim    1869
# Name: Genero, dtype: int64

# %%
grupo_nao = dados.query('Evadiu == "Nao"').sample(n = 1890, random_state = 10)
grupo_nao
# Out:
#        IDcliente Evadiu  Genero Idoso Parceiro Dependencia  Meses_de_contrato  \
# 1597  2324-EFHVG    Nao   Homem   Nao      Nao         Nao                 64
# 4287  6035-RIIOM    Nao  Mulher   Nao      Nao         Nao                 54
# 778   1134-YWTYF    Nao   Homem   Nao      Sim         Nao                 27
# 1037  1498-NHTLT    Nao   Homem   Nao      Sim         Sim                 59
# 2747  3908-MKIMJ    Nao   Homem   Sim      Sim         Nao                 68
# ...          ...    ...     ...   ...      ...         ...                ...
# 6877  9770-KXGQU    Nao  Mulher   Nao      Nao         Nao                 53
# 1703  2480-JZOSN    Nao  Mulher   Nao      Sim         Nao                  1
# 1086  1580-BMCMR    Nao   Homem   Sim      Nao         Nao                 19
# 6715  9537-VHDTA    Nao  Mulher   Nao      Nao         Sim                  1
# 5469  7695-PKLCZ    Nao  Mulher   Nao      Nao         Nao                 68
#
#      Servico_celular     linhas_multiplas Tipo_contrato  ... Gasto_mensal  \
# 1597             Sim                  Sim       Bianual  ...       104.40
# 4287             Sim                  Sim       Bianual  ...        97.20
# 778              Sim                  Nao     Mes a Mes  ...        53.80
# 1037             Sim                  Nao       Bianual  ...        86.75
# 2747             Nao  Sem servico celular       Bianual  ...        41.95
# ...              ...                  ...           ...  ...          ...
# 6877             Sim                  Sim         Anual  ...        98.60
# 1703             Sim                  Nao     Mes a Mes  ...        20.65
# 1086             Sim                  Nao     Mes a Mes  ...        87.30
# 6715             Sim                  Nao     Mes a Mes  ...        51.20
# 5469             Sim                  Nao       Bianual  ...        20.50
#
#      Gasto_total  Servico_internet      Seguranca_online  \
# 1597     6692.65      Fibra optica                   Nao
# 4287     5129.45      Fibra optica                   Nao
# 778      1389.85               DSL                   Nao
# 1037     5186.00               DSL                   Sim
# 2747     2965.75               DSL                   Sim
# ...          ...               ...                   ...
# 6877     5311.85      Fibra optica                   Sim
# 1703       20.65               Nao  Sem servico internet
# 1086     1637.30      Fibra optica                   Sim
# 6715       51.20               DSL                   Sim
# 5469     1424.90               Nao  Sem servico internet
#
#              Backup_online  Protecao_de_aparelho       Suporte_tecnico  \
# 1597                   Sim                   Sim                   Nao
# 4287                   Sim                   Nao                   Nao
# 778                    Sim                   Nao                   Sim
# 1037                   Sim                   Sim                   Sim
# 2747                   Sim                   Sim                   Nao
# ...                    ...                   ...                   ...
# 6877                   Sim                   Sim                   Nao
# 1703  Sem servico internet  Sem servico internet  Sem servico internet
# 1086                   Nao                   Nao                   Nao
# 6715                   Nao                   Nao                   Nao
# 5469  Sem servico internet  Sem servico internet  Sem servico internet
#
#              Assinatura_tv      Assinatura_filme Gasto_diario
# 1597                   Sim                   Sim     3.480000
# 4287                   Sim                   Sim     3.240000
# 778                    Nao                   Nao     1.793333
# 1037                   Sim                   Sim     2.891667
# 2747                   Nao                   Nao     1.398333
# ...                    ...                   ...          ...
# 6877                   Sim                   Nao     3.286667
# 1703  Sem servico internet  Sem servico internet     0.688333
# 1086                   Nao                   Sim     2.910000
# 6715                   Nao                   Nao     1.706667
# 5469  Sem servico internet  Sem servico internet     0.683333
#
# [1890 rows x 22 columns]

# %%
grupo_sim = dados.query('Evadiu == "Sim"')
grupo_sim
# Out:
#        IDcliente Evadiu  Genero Idoso Parceiro Dependencia  Meses_de_contrato  \
# 2     0004-TLHLJ    Sim   Homem   Nao      Nao         Nao                  4
# 3     0011-IGKFF    Sim   Homem   Sim      Sim         Nao                 13
# 4     0013-EXCHZ    Sim  Mulher   Sim      Sim         Nao                  3
# 18    0022-TCJCI    Sim   Homem   Sim      Nao         Nao                 45
# 19    0023-HGHWL    Sim   Homem   Sim      Nao         Nao                  1
# ...          ...    ...     ...   ...      ...         ...                ...
# 7020  9961-JBNMK    Sim   Homem   Sim      Nao         Nao                 21
# 7023  9965-YOKZB    Sim   Homem   Sim      Nao         Nao                  9
# 7036  9985-MWVIX    Sim  Mulher   Nao      Nao         Nao                  1
# 7037  9986-BONCE    Sim  Mulher   Nao      Nao         Nao                  4
# 7039  9992-RRAMN    Sim   Homem   Nao      Sim         Nao                 22
#
#      Servico_celular     linhas_multiplas Tipo_contrato  ... Gasto_mensal  \
# 2                Sim                  Nao     Mes a Mes  ...        73.90
# 3                Sim                  Nao     Mes a Mes  ...        98.00
# 4                Sim                  Nao     Mes a Mes  ...        83.90
# 18               Sim                  Nao         Anual  ...        62.70
# 19               Nao  Sem servico celular     Mes a Mes  ...        25.10
# ...              ...                  ...           ...  ...          ...
# 7020             Sim                  Nao     Mes a Mes  ...        96.80
# 7023             Sim                  Sim     Mes a Mes  ...        83.85
# 7036             Sim                  Nao     Mes a Mes  ...        70.15
# 7037             Sim                  Nao     Mes a Mes  ...        20.95
# 7039             Sim                  Sim     Mes a Mes  ...        85.10
#
#      Gasto_total  Servico_internet      Seguranca_online  \
# 2         280.85      Fibra optica                   Nao
# 3        1237.85      Fibra optica                   Nao
# 4         267.40      Fibra optica                   Nao
# 18       2791.50               DSL                   Sim
# 19         25.10               DSL                   Nao
# ...          ...               ...                   ...
# 7020     2030.30      Fibra optica                   Nao
# 7023      790.15      Fibra optica                   Nao
# 7036       70.15      Fibra optica                   Nao
# 7037       85.50               Nao  Sem servico internet
# 7039     1873.70      Fibra optica                   Nao
#
#              Backup_online  Protecao_de_aparelho       Suporte_tecnico  \
# 2                      Nao                   Sim                   Nao
# 3                      Sim                   Sim                   Nao
# 4                      Nao                   Nao                   Sim
# 18                     Nao                   Sim                   Nao
# 19                     Nao                   Nao                   Nao
# ...                    ...                   ...                   ...
# 7020                   Nao                   Sim                   Nao
# 7023                   Nao                   Nao                   Nao
# 7036                   Nao                   Nao                   Nao
# 7037  Sem servico internet  Sem servico internet  Sem servico internet
# 7039                   Nao                   Nao                   Nao
#
#              Assinatura_tv      Assinatura_filme Gasto_diario
# 2                      Nao                   Nao     2.463333
# 3                      Sim                   Sim     3.266667
# 4                      Sim                   Nao     2.796667
# 18                     Nao                   Sim     2.090000
# 19                     Nao                   Nao     0.836667
# ...                    ...                   ...          ...
# 7020                   Sim                   Sim     3.226667
# 7023                   Nao                   Sim     2.795000
# 7036                   Nao                   Nao     2.338333
# 7037  Sem servico internet  Sem servico internet     0.698333
# 7039                   Nao                   Sim     2.836667
#
# [1869 rows x 22 columns]

# %%
dados_balanceado = pd.concat([grupo_nao, grupo_sim],axis = 0)
dados_balanceado
# Out:
#        IDcliente Evadiu  Genero Idoso Parceiro Dependencia  Meses_de_contrato  \
# 1597  2324-EFHVG    Nao   Homem   Nao      Nao         Nao                 64
# 4287  6035-RIIOM    Nao  Mulher   Nao      Nao         Nao                 54
# 778   1134-YWTYF    Nao   Homem   Nao      Sim         Nao                 27
# 1037  1498-NHTLT    Nao   Homem   Nao      Sim         Sim                 59
# 2747  3908-MKIMJ    Nao   Homem   Sim      Sim         Nao                 68
# ...          ...    ...     ...   ...      ...         ...                ...
# 7020  9961-JBNMK    Sim   Homem   Sim      Nao         Nao                 21
# 7023  9965-YOKZB    Sim   Homem   Sim      Nao         Nao                  9
# 7036  9985-MWVIX    Sim  Mulher   Nao      Nao         Nao                  1
# 7037  9986-BONCE    Sim  Mulher   Nao      Nao         Nao                  4
# 7039  9992-RRAMN    Sim   Homem   Nao      Sim         Nao                 22
#
#      Servico_celular     linhas_multiplas Tipo_contrato  ... Gasto_mensal  \
# 1597             Sim                  Sim       Bianual  ...       104.40
# 4287             Sim                  Sim       Bianual  ...        97.20
# 778              Sim                  Nao     Mes a Mes  ...        53.80
# 1037             Sim                  Nao       Bianual  ...        86.75
# 2747             Nao  Sem servico celular       Bianual  ...        41.95
# ...              ...                  ...           ...  ...          ...
# 7020             Sim                  Nao     Mes a Mes  ...        96.80
# 7023             Sim                  Sim     Mes a Mes  ...        83.85
# 7036             Sim                  Nao     Mes a Mes  ...        70.15
# 7037             Sim                  Nao     Mes a Mes  ...        20.95
# 7039             Sim                  Sim     Mes a Mes  ...        85.10
#
#      Gasto_total  Servico_internet      Seguranca_online  \
# 1597     6692.65      Fibra optica                   Nao
# 4287     5129.45      Fibra optica                   Nao
# 778      1389.85               DSL                   Nao
# 1037     5186.00               DSL                   Sim
# 2747     2965.75               DSL                   Sim
# ...          ...               ...                   ...
# 7020     2030.30      Fibra optica                   Nao
# 7023      790.15      Fibra optica                   Nao
# 7036       70.15      Fibra optica                   Nao
# 7037       85.50               Nao  Sem servico internet
# 7039     1873.70      Fibra optica                   Nao
#
#              Backup_online  Protecao_de_aparelho       Suporte_tecnico  \
# 1597                   Sim                   Sim                   Nao
# 4287                   Sim                   Nao                   Nao
# 778                    Sim                   Nao                   Sim
# 1037                   Sim                   Sim                   Sim
# 2747                   Sim                   Sim                   Nao
# ...                    ...                   ...                   ...
# 7020                   Nao                   Sim                   Nao
# 7023                   Nao                   Nao                   Nao
# 7036                   Nao                   Nao                   Nao
# 7037  Sem servico internet  Sem servico internet  Sem servico internet
# 7039                   Nao                   Nao                   Nao
#
#              Assinatura_tv      Assinatura_filme Gasto_diario
# 1597                   Sim                   Sim     3.480000
# 4287                   Sim                   Sim     3.240000
# 778                    Nao                   Nao     1.793333
# 1037                   Sim                   Sim     2.891667
# 2747                   Nao                   Nao     1.398333
# ...                    ...                   ...          ...
# 7020                   Sim                   Sim     3.226667
# 7023                   Nao                   Sim     2.795000
# 7036                   Nao                   Nao     2.338333
# 7037  Sem servico internet  Sem servico internet     0.698333
# 7039                   Nao                   Sim     2.836667
#
# [3759 rows x 22 columns]

# %% [markdown]
# ## 1º Modelo: **Modelo de Classificação**
#
# Modelo leva em consideração os sims e nãos dos dados de variáveis categóricas. AS variáveis que tem mais de uma alternativa de escolha serão transformados em colunas de sim e não.
# Não -> 0
# Sim -> 1

# %%
variaveis_cat = dados_balanceado[['Evadiu','Idoso',
 'Parceiro',
 'Dependencia',
 'Tipo_contrato',
 'Fatura_online',
 'Metodo_pagamento',
 'Servico_internet',
 'Assinatura_tv',
 'Assinatura_filme']].copy()
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Tipo_contrato Fatura_online  \
# 1597    Nao   Nao      Nao         Nao       Bianual           Sim
# 4287    Nao   Nao      Nao         Nao       Bianual           Sim
# 778     Nao   Nao      Sim         Nao     Mes a Mes           Sim
# 1037    Nao   Nao      Sim         Sim       Bianual           Sim
# 2747    Nao   Sim      Sim         Nao       Bianual           Sim
# 2491    Nao   Nao      Sim         Nao     Mes a Mes           Nao
# 6036    Nao   Nao      Sim         Nao         Anual           Sim
# 1617    Nao   Nao      Sim         Sim     Mes a Mes           Sim
# 2080    Nao   Nao      Nao         Nao       Bianual           Nao
# 6701    Nao   Nao      Nao         Nao     Mes a Mes           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme
# 1597              Sim
# 4287              Sim
# 778               Nao
# 1037              Sim
# 2747              Nao
# 2491              Nao
# 6036              Sim
# 1617              Sim
# 2080              Sim
# 6701              Nao

# %% [markdown]
# ### 1. Alterando Tipo_contrato

# %%
anual = variaveis_cat['Tipo_contrato'].isin(['Anual'])
lista_anual = []
for valor in anual.values:
  if valor == True:
    lista_anual.append(1)
  else:
    lista_anual.append(0)

# %%
variaveis_cat['Contrato_anual'] = lista_anual
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Tipo_contrato Fatura_online  \
# 1597    Nao   Nao      Nao         Nao       Bianual           Sim
# 4287    Nao   Nao      Nao         Nao       Bianual           Sim
# 778     Nao   Nao      Sim         Nao     Mes a Mes           Sim
# 1037    Nao   Nao      Sim         Sim       Bianual           Sim
# 2747    Nao   Sim      Sim         Nao       Bianual           Sim
# 2491    Nao   Nao      Sim         Nao     Mes a Mes           Nao
# 6036    Nao   Nao      Sim         Nao         Anual           Sim
# 1617    Nao   Nao      Sim         Sim     Mes a Mes           Sim
# 2080    Nao   Nao      Nao         Nao       Bianual           Nao
# 6701    Nao   Nao      Nao         Nao     Mes a Mes           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme  Contrato_anual
# 1597              Sim               0
# 4287              Sim               0
# 778               Nao               0
# 1037              Sim               0
# 2747              Nao               0
# 2491              Nao               0
# 6036              Sim               1
# 1617              Sim               0
# 2080              Sim               0
# 6701              Nao               0

# %%
mes = variaveis_cat['Tipo_contrato'].isin(['Mes a Mes'])
lista_mes = []
for valor in mes.values:
  if valor == True:
    lista_mes.append(1)
  else:
    lista_mes.append(0)
variaveis_cat['Contrato_mes'] = lista_mes
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Tipo_contrato Fatura_online  \
# 1597    Nao   Nao      Nao         Nao       Bianual           Sim
# 4287    Nao   Nao      Nao         Nao       Bianual           Sim
# 778     Nao   Nao      Sim         Nao     Mes a Mes           Sim
# 1037    Nao   Nao      Sim         Sim       Bianual           Sim
# 2747    Nao   Sim      Sim         Nao       Bianual           Sim
# 2491    Nao   Nao      Sim         Nao     Mes a Mes           Nao
# 6036    Nao   Nao      Sim         Nao         Anual           Sim
# 1617    Nao   Nao      Sim         Sim     Mes a Mes           Sim
# 2080    Nao   Nao      Nao         Nao       Bianual           Nao
# 6701    Nao   Nao      Nao         Nao     Mes a Mes           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme  Contrato_anual  Contrato_mes
# 1597              Sim               0             0
# 4287              Sim               0             0
# 778               Nao               0             1
# 1037              Sim               0             0
# 2747              Nao               0             0
# 2491              Nao               0             1
# 6036              Sim               1             0
# 1617              Sim               0             1
# 2080              Sim               0             0
# 6701              Nao               0             1

# %%
bianual = variaveis_cat['Tipo_contrato'].isin(['Bianual'])
lista_bianual = []
for valor in bianual.values:
  if valor == True:
    lista_bianual.append(1)
  else:
    lista_bianual.append(0)
variaveis_cat['Contrato_bianual'] = lista_bianual
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Tipo_contrato Fatura_online  \
# 1597    Nao   Nao      Nao         Nao       Bianual           Sim
# 4287    Nao   Nao      Nao         Nao       Bianual           Sim
# 778     Nao   Nao      Sim         Nao     Mes a Mes           Sim
# 1037    Nao   Nao      Sim         Sim       Bianual           Sim
# 2747    Nao   Sim      Sim         Nao       Bianual           Sim
# 2491    Nao   Nao      Sim         Nao     Mes a Mes           Nao
# 6036    Nao   Nao      Sim         Nao         Anual           Sim
# 1617    Nao   Nao      Sim         Sim     Mes a Mes           Sim
# 2080    Nao   Nao      Nao         Nao       Bianual           Nao
# 6701    Nao   Nao      Nao         Nao     Mes a Mes           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1
# 2491              Nao               0             1                 0
# 6036              Sim               1             0                 0
# 1617              Sim               0             1                 0
# 2080              Sim               0             0                 1
# 6701              Nao               0             1                 0

# %%
variaveis_cat.drop(['Tipo_contrato'], axis = 1, inplace = True)
variaveis_cat.head()
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online  \
# 1597    Nao   Nao      Nao         Nao           Sim
# 4287    Nao   Nao      Nao         Nao           Sim
# 778     Nao   Nao      Sim         Nao           Sim
# 1037    Nao   Nao      Sim         Sim           Sim
# 2747    Nao   Sim      Sim         Nao           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1

# %% [markdown]
# ### 2. Alterando Metodo_pagamento

# %%
variaveis_cat['Metodo_pagamento'].unique()
# Out:
# array(['Transferencia Bancaria (automatico)', 'Cheque Eletronico',
#        'Cartao Credito (automatico)', 'Cheque por Email'], dtype=object)

# %%
lista_ce = []
for valor in variaveis_cat['Metodo_pagamento'].isin(['Cheque por Email']):
  if valor == True:
    lista_ce.append(1)
  else:
    lista_ce.append(0)
variaveis_cat['Pagamento_Cheque_Email'] = lista_ce
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online  \
# 1597    Nao   Nao      Nao         Nao           Sim
# 4287    Nao   Nao      Nao         Nao           Sim
# 778     Nao   Nao      Sim         Nao           Sim
# 1037    Nao   Nao      Sim         Sim           Sim
# 2747    Nao   Sim      Sim         Nao           Sim
# 2491    Nao   Nao      Sim         Nao           Nao
# 6036    Nao   Nao      Sim         Nao           Sim
# 1617    Nao   Nao      Sim         Sim           Sim
# 2080    Nao   Nao      Nao         Nao           Nao
# 6701    Nao   Nao      Nao         Nao           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual  \
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1
# 2491              Nao               0             1                 0
# 6036              Sim               1             0                 0
# 1617              Sim               0             1                 0
# 2080              Sim               0             0                 1
# 6701              Nao               0             1                 0
#
#       Pagamento_Cheque_Email
# 1597                       0
# 4287                       0
# 778                        0
# 1037                       0
# 2747                       0
# 2491                       0
# 6036                       0
# 1617                       0
# 2080                       1
# 6701                       0

# %%
lista_cel = []
for valor in variaveis_cat['Metodo_pagamento'].isin(['Cheque Eletronico']):
  if valor == True:
    lista_cel.append(1)
  else:
    lista_cel.append(0)
variaveis_cat['Pagamento_Cheque_Eletrico'] = lista_cel
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online  \
# 1597    Nao   Nao      Nao         Nao           Sim
# 4287    Nao   Nao      Nao         Nao           Sim
# 778     Nao   Nao      Sim         Nao           Sim
# 1037    Nao   Nao      Sim         Sim           Sim
# 2747    Nao   Sim      Sim         Nao           Sim
# 2491    Nao   Nao      Sim         Nao           Nao
# 6036    Nao   Nao      Sim         Nao           Sim
# 1617    Nao   Nao      Sim         Sim           Sim
# 2080    Nao   Nao      Nao         Nao           Nao
# 6701    Nao   Nao      Nao         Nao           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual  \
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1
# 2491              Nao               0             1                 0
# 6036              Sim               1             0                 0
# 1617              Sim               0             1                 0
# 2080              Sim               0             0                 1
# 6701              Nao               0             1                 0
#
#       Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico
# 1597                       0                          0
# 4287                       0                          0
# 778                        0                          1
# 1037                       0                          1
# 2747                       0                          1
# 2491                       0                          0
# 6036                       0                          0
# 1617                       0                          0
# 2080                       1                          0
# 6701                       0                          0

# %%
lista_cartao = []
for valor in variaveis_cat['Metodo_pagamento'].isin(['Cartao Credito (automatico)']):
  if valor == True:
    lista_cartao.append(1)
  else:
    lista_cartao.append(0)
variaveis_cat['Pagamento_Cartao_credito'] = lista_cartao
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online  \
# 1597    Nao   Nao      Nao         Nao           Sim
# 4287    Nao   Nao      Nao         Nao           Sim
# 778     Nao   Nao      Sim         Nao           Sim
# 1037    Nao   Nao      Sim         Sim           Sim
# 2747    Nao   Sim      Sim         Nao           Sim
# 2491    Nao   Nao      Sim         Nao           Nao
# 6036    Nao   Nao      Sim         Nao           Sim
# 1617    Nao   Nao      Sim         Sim           Sim
# 2080    Nao   Nao      Nao         Nao           Nao
# 6701    Nao   Nao      Nao         Nao           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual  \
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1
# 2491              Nao               0             1                 0
# 6036              Sim               1             0                 0
# 1617              Sim               0             1                 0
# 2080              Sim               0             0                 1
# 6701              Nao               0             1                 0
#
#       Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                       0                          0
# 4287                       0                          0
# 778                        0                          1
# 1037                       0                          1
# 2747                       0                          1
# 2491                       0                          0
# 6036                       0                          0
# 1617                       0                          0
# 2080                       1                          0
# 6701                       0                          0
#
#       Pagamento_Cartao_credito
# 1597                         0
# 4287                         0
# 778                          0
# 1037                         0
# 2747                         0
# 2491                         0
# 6036                         1
# 1617                         0
# 2080                         0
# 6701                         0

# %%
lista_trans = []
for valor in variaveis_cat['Metodo_pagamento'].isin(['Transferencia Bancaria (automatico)']):
  if valor == True:
    lista_trans.append(1)
  else:
    lista_trans.append(0)
variaveis_cat['Pagamento_Transferencia'] = lista_trans
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online  \
# 1597    Nao   Nao      Nao         Nao           Sim
# 4287    Nao   Nao      Nao         Nao           Sim
# 778     Nao   Nao      Sim         Nao           Sim
# 1037    Nao   Nao      Sim         Sim           Sim
# 2747    Nao   Sim      Sim         Nao           Sim
# 2491    Nao   Nao      Sim         Nao           Nao
# 6036    Nao   Nao      Sim         Nao           Sim
# 1617    Nao   Nao      Sim         Sim           Sim
# 2080    Nao   Nao      Nao         Nao           Nao
# 6701    Nao   Nao      Nao         Nao           Sim
#
#                          Metodo_pagamento Servico_internet Assinatura_tv  \
# 1597  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 4287  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 778                     Cheque Eletronico              DSL           Nao
# 1037                    Cheque Eletronico              DSL           Sim
# 2747                    Cheque Eletronico              DSL           Nao
# 2491  Transferencia Bancaria (automatico)              DSL           Nao
# 6036          Cartao Credito (automatico)              DSL           Nao
# 1617  Transferencia Bancaria (automatico)     Fibra optica           Sim
# 2080                     Cheque por Email              DSL           Sim
# 6701  Transferencia Bancaria (automatico)              DSL           Sim
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual  \
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1
# 2491              Nao               0             1                 0
# 6036              Sim               1             0                 0
# 1617              Sim               0             1                 0
# 2080              Sim               0             0                 1
# 6701              Nao               0             1                 0
#
#       Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                       0                          0
# 4287                       0                          0
# 778                        0                          1
# 1037                       0                          1
# 2747                       0                          1
# 2491                       0                          0
# 6036                       0                          0
# 1617                       0                          0
# 2080                       1                          0
# 6701                       0                          0
#
#       Pagamento_Cartao_credito  Pagamento_Transferencia
# 1597                         0                        1
# 4287                         0                        1
# 778                          0                        0
# 1037                         0                        0
# 2747                         0                        0
# 2491                         0                        1
# 6036                         1                        0
# 1617                         0                        1
# 2080                         0                        0
# 6701                         0                        1

# %%
variaveis_cat.drop(['Metodo_pagamento'], axis = 1, inplace = True)
variaveis_cat.head()
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Servico_internet  \
# 1597    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 4287    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 778     Nao   Nao      Sim         Nao           Sim              DSL
# 1037    Nao   Nao      Sim         Sim           Sim              DSL
# 2747    Nao   Sim      Sim         Nao           Sim              DSL
#
#      Assinatura_tv Assinatura_filme  Contrato_anual  Contrato_mes  \
# 1597           Sim              Sim               0             0
# 4287           Sim              Sim               0             0
# 778            Nao              Nao               0             1
# 1037           Sim              Sim               0             0
# 2747           Nao              Nao               0             0
#
#       Contrato_bianual  Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                 1                       0                          0
# 4287                 1                       0                          0
# 778                  0                       0                          1
# 1037                 1                       0                          1
# 2747                 1                       0                          1
#
#       Pagamento_Cartao_credito  Pagamento_Transferencia
# 1597                         0                        1
# 4287                         0                        1
# 778                          0                        0
# 1037                         0                        0
# 2747                         0                        0

# %% [markdown]
# ### 3. Alterando Servico_internet

# %%
variaveis_cat['Servico_internet'].unique()
# Out:
# array(['Fibra optica', 'DSL', 'Nao'], dtype=object)

# %%
lista_DSL = []
for valor in variaveis_cat['Servico_internet'].isin(['DSL']):
  if valor == True:
    lista_DSL.append(1)
  else:
    lista_DSL.append(0)
variaveis_cat['Internet_DSL'] = lista_DSL
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Servico_internet  \
# 1597    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 4287    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 778     Nao   Nao      Sim         Nao           Sim              DSL
# 1037    Nao   Nao      Sim         Sim           Sim              DSL
# 2747    Nao   Sim      Sim         Nao           Sim              DSL
# 2491    Nao   Nao      Sim         Nao           Nao              DSL
# 6036    Nao   Nao      Sim         Nao           Sim              DSL
# 1617    Nao   Nao      Sim         Sim           Sim     Fibra optica
# 2080    Nao   Nao      Nao         Nao           Nao              DSL
# 6701    Nao   Nao      Nao         Nao           Sim              DSL
#
#      Assinatura_tv Assinatura_filme  Contrato_anual  Contrato_mes  \
# 1597           Sim              Sim               0             0
# 4287           Sim              Sim               0             0
# 778            Nao              Nao               0             1
# 1037           Sim              Sim               0             0
# 2747           Nao              Nao               0             0
# 2491           Nao              Nao               0             1
# 6036           Nao              Sim               1             0
# 1617           Sim              Sim               0             1
# 2080           Sim              Sim               0             0
# 6701           Sim              Nao               0             1
#
#       Contrato_bianual  Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                 1                       0                          0
# 4287                 1                       0                          0
# 778                  0                       0                          1
# 1037                 1                       0                          1
# 2747                 1                       0                          1
# 2491                 0                       0                          0
# 6036                 0                       0                          0
# 1617                 0                       0                          0
# 2080                 1                       1                          0
# 6701                 0                       0                          0
#
#       Pagamento_Cartao_credito  Pagamento_Transferencia  Internet_DSL
# 1597                         0                        1             0
# 4287                         0                        1             0
# 778                          0                        0             1
# 1037                         0                        0             1
# 2747                         0                        0             1
# 2491                         0                        1             1
# 6036                         1                        0             1
# 1617                         0                        1             0
# 2080                         0                        0             1
# 6701                         0                        1             1

# %%
lista_fibra = []
for valor in variaveis_cat['Servico_internet'].isin(['Fibra optica']):
  if valor == True:
    lista_fibra.append(1)
  else:
    lista_fibra.append(0)
variaveis_cat['Internet_FibraOptica'] = lista_fibra
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Servico_internet  \
# 1597    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 4287    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 778     Nao   Nao      Sim         Nao           Sim              DSL
# 1037    Nao   Nao      Sim         Sim           Sim              DSL
# 2747    Nao   Sim      Sim         Nao           Sim              DSL
# 2491    Nao   Nao      Sim         Nao           Nao              DSL
# 6036    Nao   Nao      Sim         Nao           Sim              DSL
# 1617    Nao   Nao      Sim         Sim           Sim     Fibra optica
# 2080    Nao   Nao      Nao         Nao           Nao              DSL
# 6701    Nao   Nao      Nao         Nao           Sim              DSL
#
#      Assinatura_tv Assinatura_filme  Contrato_anual  Contrato_mes  \
# 1597           Sim              Sim               0             0
# 4287           Sim              Sim               0             0
# 778            Nao              Nao               0             1
# 1037           Sim              Sim               0             0
# 2747           Nao              Nao               0             0
# 2491           Nao              Nao               0             1
# 6036           Nao              Sim               1             0
# 1617           Sim              Sim               0             1
# 2080           Sim              Sim               0             0
# 6701           Sim              Nao               0             1
#
#       Contrato_bianual  Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                 1                       0                          0
# 4287                 1                       0                          0
# 778                  0                       0                          1
# 1037                 1                       0                          1
# 2747                 1                       0                          1
# 2491                 0                       0                          0
# 6036                 0                       0                          0
# 1617                 0                       0                          0
# 2080                 1                       1                          0
# 6701                 0                       0                          0
#
#       Pagamento_Cartao_credito  Pagamento_Transferencia  Internet_DSL  \
# 1597                         0                        1             0
# 4287                         0                        1             0
# 778                          0                        0             1
# 1037                         0                        0             1
# 2747                         0                        0             1
# 2491                         0                        1             1
# 6036                         1                        0             1
# 1617                         0                        1             0
# 2080                         0                        0             1
# 6701                         0                        1             1
#
#       Internet_FibraOptica
# 1597                     1
# 4287                     1
# 778                      0
# 1037                     0
# 2747                     0
# 2491                     0
# 6036                     0
# 1617                     1
# 2080                     0
# 6701                     0

# %%
lista_nao = []
for valor in variaveis_cat['Servico_internet'].isin(['Nao']):
  if valor == True:
    lista_nao.append(1)
  else:
    lista_nao.append(0)
variaveis_cat['Internet_SemInternet'] = lista_nao
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Servico_internet  \
# 1597    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 4287    Nao   Nao      Nao         Nao           Sim     Fibra optica
# 778     Nao   Nao      Sim         Nao           Sim              DSL
# 1037    Nao   Nao      Sim         Sim           Sim              DSL
# 2747    Nao   Sim      Sim         Nao           Sim              DSL
# 2491    Nao   Nao      Sim         Nao           Nao              DSL
# 6036    Nao   Nao      Sim         Nao           Sim              DSL
# 1617    Nao   Nao      Sim         Sim           Sim     Fibra optica
# 2080    Nao   Nao      Nao         Nao           Nao              DSL
# 6701    Nao   Nao      Nao         Nao           Sim              DSL
#
#      Assinatura_tv Assinatura_filme  Contrato_anual  Contrato_mes  \
# 1597           Sim              Sim               0             0
# 4287           Sim              Sim               0             0
# 778            Nao              Nao               0             1
# 1037           Sim              Sim               0             0
# 2747           Nao              Nao               0             0
# 2491           Nao              Nao               0             1
# 6036           Nao              Sim               1             0
# 1617           Sim              Sim               0             1
# 2080           Sim              Sim               0             0
# 6701           Sim              Nao               0             1
#
#       Contrato_bianual  Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                 1                       0                          0
# 4287                 1                       0                          0
# 778                  0                       0                          1
# 1037                 1                       0                          1
# 2747                 1                       0                          1
# 2491                 0                       0                          0
# 6036                 0                       0                          0
# 1617                 0                       0                          0
# 2080                 1                       1                          0
# 6701                 0                       0                          0
#
#       Pagamento_Cartao_credito  Pagamento_Transferencia  Internet_DSL  \
# 1597                         0                        1             0
# 4287                         0                        1             0
# 778                          0                        0             1
# 1037                         0                        0             1
# 2747                         0                        0             1
# 2491                         0                        1             1
# 6036                         1                        0             1
# 1617                         0                        1             0
# 2080                         0                        0             1
# 6701                         0                        1             1
#
#       Internet_FibraOptica  Internet_SemInternet
# 1597                     1                     0
# 4287                     1                     0
# 778                      0                     0
# 1037                     0                     0
# 2747                     0                     0
# 2491                     0                     0
# 6036                     0                     0
# 1617                     1                     0
# 2080                     0                     0
# 6701                     0                     0

# %%
variaveis_cat.drop(['Servico_internet'], axis = 1, inplace = True)
variaveis_cat.head()
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Assinatura_tv  \
# 1597    Nao   Nao      Nao         Nao           Sim           Sim
# 4287    Nao   Nao      Nao         Nao           Sim           Sim
# 778     Nao   Nao      Sim         Nao           Sim           Nao
# 1037    Nao   Nao      Sim         Sim           Sim           Sim
# 2747    Nao   Sim      Sim         Nao           Sim           Nao
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual  \
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1
#
#       Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                       0                          0
# 4287                       0                          0
# 778                        0                          1
# 1037                       0                          1
# 2747                       0                          1
#
#       Pagamento_Cartao_credito  Pagamento_Transferencia  Internet_DSL  \
# 1597                         0                        1             0
# 4287                         0                        1             0
# 778                          0                        0             1
# 1037                         0                        0             1
# 2747                         0                        0             1
#
#       Internet_FibraOptica  Internet_SemInternet
# 1597                     1                     0
# 4287                     1                     0
# 778                      0                     0
# 1037                     0                     0
# 2747                     0                     0

# %% [markdown]
# ### 4. Alterando as variáveis Assinatura.
# Estas apresentam 3 valores, sendo um deles repetido na variáveis Sem internet

# %%
variaveis_cat['Assinatura_tv'].unique()
# Out:
# array(['Sim', 'Nao', 'Sem servico internet'], dtype=object)

# %%
lista_Assnao = []
for valor in variaveis_cat['Assinatura_tv'].isin(['Sim']):
  if valor == True:
    lista_Assnao.append(1)
  else:
    lista_Assnao.append(0)
variaveis_cat['Tv'] = lista_Assnao
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Assinatura_tv  \
# 1597    Nao   Nao      Nao         Nao           Sim           Sim
# 4287    Nao   Nao      Nao         Nao           Sim           Sim
# 778     Nao   Nao      Sim         Nao           Sim           Nao
# 1037    Nao   Nao      Sim         Sim           Sim           Sim
# 2747    Nao   Sim      Sim         Nao           Sim           Nao
# 2491    Nao   Nao      Sim         Nao           Nao           Nao
# 6036    Nao   Nao      Sim         Nao           Sim           Nao
# 1617    Nao   Nao      Sim         Sim           Sim           Sim
# 2080    Nao   Nao      Nao         Nao           Nao           Sim
# 6701    Nao   Nao      Nao         Nao           Sim           Sim
#
#      Assinatura_filme  Contrato_anual  Contrato_mes  Contrato_bianual  \
# 1597              Sim               0             0                 1
# 4287              Sim               0             0                 1
# 778               Nao               0             1                 0
# 1037              Sim               0             0                 1
# 2747              Nao               0             0                 1
# 2491              Nao               0             1                 0
# 6036              Sim               1             0                 0
# 1617              Sim               0             1                 0
# 2080              Sim               0             0                 1
# 6701              Nao               0             1                 0
#
#       Pagamento_Cheque_Email  Pagamento_Cheque_Eletrico  \
# 1597                       0                          0
# 4287                       0                          0
# 778                        0                          1
# 1037                       0                          1
# 2747                       0                          1
# 2491                       0                          0
# 6036                       0                          0
# 1617                       0                          0
# 2080                       1                          0
# 6701                       0                          0
#
#       Pagamento_Cartao_credito  Pagamento_Transferencia  Internet_DSL  \
# 1597                         0                        1             0
# 4287                         0                        1             0
# 778                          0                        0             1
# 1037                         0                        0             1
# 2747                         0                        0             1
# 2491                         0                        1             1
# 6036                         1                        0             1
# 1617                         0                        1             0
# 2080                         0                        0             1
# 6701                         0                        1             1
#
#       Internet_FibraOptica  Internet_SemInternet  Tv
# 1597                     1                     0   1
# 4287                     1                     0   1
# 778                      0                     0   0
# 1037                     0                     0   1
# 2747                     0                     0   0
# 2491                     0                     0   0
# 6036                     0                     0   0
# 1617                     1                     0   1
# 2080                     0                     0   1
# 6701                     0                     0   1

# %%
variaveis_cat.drop(['Assinatura_tv'], axis = 1, inplace = True)
variaveis_cat.head()
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Assinatura_filme  \
# 1597    Nao   Nao      Nao         Nao           Sim              Sim
# 4287    Nao   Nao      Nao         Nao           Sim              Sim
# 778     Nao   Nao      Sim         Nao           Sim              Nao
# 1037    Nao   Nao      Sim         Sim           Sim              Sim
# 2747    Nao   Sim      Sim         Nao           Sim              Nao
#
#       Contrato_anual  Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597               0             0                 1                       0
# 4287               0             0                 1                       0
# 778                0             1                 0                       0
# 1037               0             0                 1                       0
# 2747               0             0                 1                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
#
#       Internet_SemInternet  Tv
# 1597                     0   1
# 4287                     0   1
# 778                      0   0
# 1037                     0   1
# 2747                     0   0

# %%
lista_Ass = []
for valor in variaveis_cat['Assinatura_filme'].isin(['Sim']):
  if valor == True:
    lista_Ass.append(1)
  else:
    lista_Ass.append(0)
variaveis_cat['Filme_sim'] = lista_Ass
variaveis_cat.head(10)
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online Assinatura_filme  \
# 1597    Nao   Nao      Nao         Nao           Sim              Sim
# 4287    Nao   Nao      Nao         Nao           Sim              Sim
# 778     Nao   Nao      Sim         Nao           Sim              Nao
# 1037    Nao   Nao      Sim         Sim           Sim              Sim
# 2747    Nao   Sim      Sim         Nao           Sim              Nao
# 2491    Nao   Nao      Sim         Nao           Nao              Nao
# 6036    Nao   Nao      Sim         Nao           Sim              Sim
# 1617    Nao   Nao      Sim         Sim           Sim              Sim
# 2080    Nao   Nao      Nao         Nao           Nao              Sim
# 6701    Nao   Nao      Nao         Nao           Sim              Nao
#
#       Contrato_anual  Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597               0             0                 1                       0
# 4287               0             0                 1                       0
# 778                0             1                 0                       0
# 1037               0             0                 1                       0
# 2747               0             0                 1                       0
# 2491               0             1                 0                       0
# 6036               1             0                 0                       0
# 1617               0             1                 0                       0
# 2080               0             0                 1                       1
# 6701               0             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
# 2491                          0                         0
# 6036                          0                         1
# 1617                          0                         0
# 2080                          0                         0
# 6701                          0                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
# 2491                        1             1                     0
# 6036                        0             1                     0
# 1617                        1             0                     1
# 2080                        0             1                     0
# 6701                        1             1                     0
#
#       Internet_SemInternet  Tv  Filme_sim
# 1597                     0   1          1
# 4287                     0   1          1
# 778                      0   0          0
# 1037                     0   1          1
# 2747                     0   0          0
# 2491                     0   0          0
# 6036                     0   0          1
# 1617                     0   1          1
# 2080                     0   1          1
# 6701                     0   1          0

# %%
variaveis_cat.drop(['Assinatura_filme'], axis = 1, inplace = True)
variaveis_cat.head()
# Out:
#      Evadiu Idoso Parceiro Dependencia Fatura_online  Contrato_anual  \
# 1597    Nao   Nao      Nao         Nao           Sim               0
# 4287    Nao   Nao      Nao         Nao           Sim               0
# 778     Nao   Nao      Sim         Nao           Sim               0
# 1037    Nao   Nao      Sim         Sim           Sim               0
# 2747    Nao   Sim      Sim         Nao           Sim               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
#
#       Internet_SemInternet  Tv  Filme_sim
# 1597                     0   1          1
# 4287                     0   1          1
# 778                      0   0          0
# 1037                     0   1          1
# 2747                     0   0          0

# %% [markdown]
# ### 5. Alterando sims e não de outras variáveis

# %%
traducao ={
    'Sim':1,
    'Nao':0
}

# %%
for coluna in ['Evadiu','Idoso','Parceiro','Dependencia','Fatura_online']:
  variaveis_cat[coluna] = variaveis_cat[coluna].map(traducao)
variaveis_cat.head(10)
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
# 2491       0      0         1            0              0               0
# 6036       0      0         1            0              1               1
# 1617       0      0         1            1              1               0
# 2080       0      0         0            0              0               0
# 6701       0      0         0            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
# 2491             1                 0                       0
# 6036             0                 0                       0
# 1617             1                 0                       0
# 2080             0                 1                       1
# 6701             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
# 2491                          0                         0
# 6036                          0                         1
# 1617                          0                         0
# 2080                          0                         0
# 6701                          0                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
# 2491                        1             1                     0
# 6036                        0             1                     0
# 1617                        1             0                     1
# 2080                        0             1                     0
# 6701                        1             1                     0
#
#       Internet_SemInternet  Tv  Filme_sim
# 1597                     0   1          1
# 4287                     0   1          1
# 778                      0   0          0
# 1037                     0   1          1
# 2747                     0   0          0
# 2491                     0   0          0
# 6036                     0   0          1
# 1617                     0   1          1
# 2080                     0   1          1
# 6701                     0   1          0

# %% [markdown]
# ### 6. Estudando os dados

# %%
variaveis_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3759 entries, 1597 to 7039
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Evadiu                     3759 non-null   int64
#  1   Idoso                      3759 non-null   int64
#  2   Parceiro                   3759 non-null   int64
#  3   Dependencia                3759 non-null   int64
#  4   Fatura_online              3759 non-null   int64
#  5   Contrato_anual             3759 non-null   int64
#  6   Contrato_mes               3759 non-null   int64
#  7   Contrato_bianual           3759 non-null   int64
#  8   Pagamento_Cheque_Email     3759 non-null   int64
#  9   Pagamento_Cheque_Eletrico  3759 non-null   int64
#  10  Pagamento_Cartao_credito   3759 non-null   int64
#  11  Pagamento_Transferencia    3759 non-null   int64
#  12  Internet_DSL               3759 non-null   int64
#  13  Internet_FibraOptica       3759 non-null   int64
#  14  Internet_SemInternet       3759 non-null   int64
#  15  Tv                         3759 non-null   int64
#  16  Filme_sim                  3759 non-null   int64
# dtypes: int64(17)
# memory usage: 528.6 KB

# %%
nao_evasores = round(variaveis_cat['Evadiu'].value_counts(normalize = True)[0],1)
evasores = round(variaveis_cat['Evadiu'].value_counts(normalize = True)[1],1)
print(nao_evasores, evasores)
# Out:
# 0.5 0.5

# %%
print(f'Temos {len(variaveis_cat)} dados. Sendo que {round(len(variaveis_cat) * nao_evasores,0)} são Não Evasores, {round(len(variaveis_cat) * evasores,0)} são Evasores')
# Out:
# Temos 3759 dados. Sendo que 1880.0 são Não Evasores, 1880.0 são Evasores

# %% [markdown]
# Para cada 1 Evasor existe pouco mais que 2 Permanecentes

# %% [markdown]
# ### 7. **Criando o Modelo**

# %%
variaveis_cat.columns
# Out:
# Index(['Evadiu', 'Idoso', 'Parceiro', 'Dependencia', 'Fatura_online',
#        'Contrato_anual', 'Contrato_mes', 'Contrato_bianual',
#        'Pagamento_Cheque_Email', 'Pagamento_Cheque_Eletrico',
#        'Pagamento_Cartao_credito', 'Pagamento_Transferencia', 'Internet_DSL',
#        'Internet_FibraOptica', 'Internet_SemInternet', 'Tv', 'Filme_sim'],
#       dtype='object')

# %%
x = variaveis_cat[['Idoso', 'Parceiro', 'Dependencia', 'Fatura_online',
       'Contrato_anual', 'Contrato_mes', 'Contrato_bianual',
       'Pagamento_Cheque_Email', 'Pagamento_Cheque_Eletrico',
       'Pagamento_Cartao_credito', 'Pagamento_Transferencia', 'Internet_DSL',
       'Internet_FibraOptica', 'Internet_SemInternet', 'Tv', 'Filme_sim']]
x.head()
# Out:
#       Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597      0         0            0              1               0
# 4287      0         0            0              1               0
# 778       0         1            0              1               0
# 1037      0         1            1              1               0
# 2747      1         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
#
#       Internet_SemInternet  Tv  Filme_sim
# 1597                     0   1          1
# 4287                     0   1          1
# 778                      0   0          0
# 1037                     0   1          1
# 2747                     0   0          0

# %%
y = variaveis_cat['Evadiu']
y.head()
# Out:
# 1597    0
# 4287    0
# 778     0
# 1037    0
# 2747    0
# Name: Evadiu, dtype: int64

# %%
seed = np.random.seed = 10

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.2,random_state = seed, stratify = y)
print(treino_x.shape)
print(teste_x.shape)

modelo = LinearSVC()
modelo.fit(treino_x,treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y,previsoes)*100
print('A acuracia é de %.2f%%' %acuracia)
# Out:
# (3007, 16)
# (752, 16)
# A acuracia é de 75.27%

# %%
dummy = DummyClassifier()
dummy.fit(treino_x, treino_y)
previsoesDummy = dummy.predict(teste_x)
acuracia = accuracy_score(teste_y,previsoesDummy)*100
print('A acuracia é de %.2f%%' %acuracia)
# Out:
# A acuracia é de 50.27%

# %% [markdown]
# * Com uma acurácia de 50.27% do Dummy e 78.07% do modelo temos que o modelo está bom, mas vamos criar um novo ou melhorar este.
# * Neste modelo somente foi usado as variáveis categóricas. Deve-se implementar as demais variáveis.

# %% [markdown]
# ## 2º Modelo: Transformando Variáveis Quantitativas em Categóricas

# %% [markdown]
# ### Meses de Contrato

# %%
dados.columns
# Out:
# Index(['IDcliente', 'Evadiu', 'Genero', 'Idoso', 'Parceiro', 'Dependencia',
#        'Meses_de_contrato', 'Servico_celular', 'linhas_multiplas',
#        'Tipo_contrato', 'Fatura_online', 'Metodo_pagamento', 'Gasto_mensal',
#        'Gasto_total', 'Servico_internet', 'Seguranca_online', 'Backup_online',
#        'Protecao_de_aparelho', 'Suporte_tecnico', 'Assinatura_tv',
#        'Assinatura_filme', 'Gasto_diario'],
#       dtype='object')

# %%
variaveis_quanti = dados_balanceado[['Gasto_total','Gasto_mensal','Gasto_diario','Meses_de_contrato']]
variaveis_quanti['Evadiu'] = variaveis_cat['Evadiu'].copy()
variaveis_quanti
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Gasto_total  Gasto_mensal  Gasto_diario  Meses_de_contrato  Evadiu
# 1597      6692.65        104.40      3.480000                 64       0
# 4287      5129.45         97.20      3.240000                 54       0
# 778       1389.85         53.80      1.793333                 27       0
# 1037      5186.00         86.75      2.891667                 59       0
# 2747      2965.75         41.95      1.398333                 68       0
# ...           ...           ...           ...                ...     ...
# 7020      2030.30         96.80      3.226667                 21       1
# 7023       790.15         83.85      2.795000                  9       1
# 7036        70.15         70.15      2.338333                  1       1
# 7037        85.50         20.95      0.698333                  4       1
# 7039      1873.70         85.10      2.836667                 22       1
#
# [3759 rows x 5 columns]

# %%
print(variaveis_quanti.groupby('Evadiu')['Meses_de_contrato'].quantile(q = 0.60))
print(variaveis_quanti.groupby('Evadiu')['Meses_de_contrato'].quantile(q = 0.25))
# Out:
# Evadiu
# 0    49.0
# 1    15.0
# Name: Meses_de_contrato, dtype: float64
# Evadiu
# 0    15.0
# 1     2.0
# Name: Meses_de_contrato, dtype: float64

# %% [markdown]
# * Temos que o quantil 15% do grupo que não evadiu é próximo o quantil 60% do grupo que evadiu. Se eu separar em 1 e 0 esta variável, dizendo que se o cliente está abaixo do quantile 60% do grupo evasor ser igual a 1 (considerado evasor) e acima ser igual a 0(permanecente) ocorrerá que considerarei 15% dos permanecentes como evasor, e 40% do evasores como permanecentes.
# Vamos fazer este teste

# %%
lista_01 = []
for item in variaveis_quanti['Meses_de_contrato'].values:
  if item <= 10:
    lista_01.append(1)
  else: lista_01.append(0)
lista_01[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
variaveis_quanti['Meses01'] = lista_01
variaveis_quanti.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Gasto_total  Gasto_mensal  Gasto_diario  Meses_de_contrato  Evadiu  \
# 1597      6692.65        104.40      3.480000                 64       0
# 4287      5129.45         97.20      3.240000                 54       0
# 778       1389.85         53.80      1.793333                 27       0
# 1037      5186.00         86.75      2.891667                 59       0
# 2747      2965.75         41.95      1.398333                 68       0
# 2491       505.95         45.90      1.530000                 12       0
# 6036      3420.50         70.55      2.351667                 48       0
# 1617      3848.00         94.90      3.163333                 41       0
# 2080      5991.05         84.70      2.823333                 70       0
# 6701      2156.25         72.45      2.415000                 31       0
#
#       Meses01
# 1597        0
# 4287        0
# 778         0
# 1037        0
# 2747        0
# 2491        0
# 6036        0
# 1617        0
# 2080        0
# 6701        0

# %% [markdown]
# ### Testando Meses de Contrato

# %%
df_modelo = variaveis_cat.copy()
df_modelo.head()
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
#
#       Internet_SemInternet  Tv  Filme_sim
# 1597                     0   1          1
# 4287                     0   1          1
# 778                      0   0          0
# 1037                     0   1          1
# 2747                     0   0          0

# %%
df_modelo['Meses01'] = variaveis_quanti['Meses01'].copy()
df_modelo
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
# ...      ...    ...       ...          ...            ...             ...
# 7020       1      1         0            0              1               0
# 7023       1      1         0            0              1               0
# 7036       1      0         0            0              1               0
# 7037       1      0         0            0              0               0
# 7039       1      0         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
# ...            ...               ...                     ...
# 7020             1                 0                       0
# 7023             1                 0                       0
# 7036             1                 0                       1
# 7037             1                 0                       0
# 7039             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
# ...                         ...                       ...
# 7020                          0                         0
# 7023                          1                         0
# 7036                          0                         0
# 7037                          0                         0
# 7039                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
# ...                       ...           ...                   ...
# 7020                        1             0                     1
# 7023                        0             0                     1
# 7036                        0             0                     1
# 7037                        1             0                     0
# 7039                        0             0                     1
#
#       Internet_SemInternet  Tv  Filme_sim  Meses01
# 1597                     0   1          1        0
# 4287                     0   1          1        0
# 778                      0   0          0        0
# 1037                     0   1          1        0
# 2747                     0   0          0        0
# ...                    ...  ..        ...      ...
# 7020                     0   1          1        0
# 7023                     0   0          1        1
# 7036                     0   0          0        1
# 7037                     1   0          0        1
# 7039                     0   0          1        0
#
# [3759 rows x 18 columns]

# %%
x= df_modelo[['Idoso', 'Parceiro', 'Dependencia', 'Fatura_online',
       'Contrato_anual', 'Contrato_mes', 'Contrato_bianual',
       'Pagamento_Cheque_Email', 'Pagamento_Cheque_Eletrico',
       'Pagamento_Cartao_credito', 'Pagamento_Transferencia', 'Internet_DSL',
       'Internet_FibraOptica', 'Internet_SemInternet', 'Tv', 'Filme_sim',
       'Meses01']]
x.head()
# Out:
#       Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597      0         0            0              1               0
# 4287      0         0            0              1               0
# 778       0         1            0              1               0
# 1037      0         1            1              1               0
# 2747      1         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
#
#       Internet_SemInternet  Tv  Filme_sim  Meses01
# 1597                     0   1          1        0
# 4287                     0   1          1        0
# 778                      0   0          0        0
# 1037                     0   1          1        0
# 2747                     0   0          0        0

# %%
y = df_modelo['Evadiu']

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np

seed = np.random.seed = 10

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,random_state = seed, stratify = y)
print(treino_x.shape)
print(teste_x.shape)

modelo = LinearSVC()
modelo.fit(treino_x,treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y,previsoes)*100
print('A acuracia do modelo é de %.2f%%' %acuracia)

from sklearn.dummy import DummyClassifier
dummy = DummyClassifier()
dummy.fit(treino_x, treino_y)
previsoesDummy = dummy.predict(teste_x)
acuracia = accuracy_score(teste_y,previsoesDummy)*100
print('A acuracia do Dummy é de %.2f%%' %acuracia)
# Out:
# (2819, 17)
# (940, 17)
# A acuracia do modelo é de 75.85%
# A acuracia do Dummy é de 50.32%

# %% [markdown]
# * Houve um aumento pequeno de 75.27% para 75.85%.
# * Foram feitos testes de como separar esses grupos, e separar pela mediana teve a melhor perfomace.
#
# ### Gasto Mensal

# %%
variaveis_quanti.query('Evadiu==1')['Gasto_mensal'].plot.box()

# %%
variaveis_quanti.query('Evadiu==0')['Gasto_mensal'].plot.box()

# %%
variaveis_quanti.query('Evadiu==1')['Gasto_mensal'].plot.box()

# %%
variaveis_quanti.groupby('Evadiu').quantile(0.45)['Gasto_mensal']
# Out:
# Evadiu
# 0    56.1525
# 1    76.0800
# Name: Gasto_mensal, dtype: float64

# %%
variaveis_quanti.groupby('Evadiu').quantile(0.25)['Gasto_mensal']
# Out:
# Evadiu
# 0    25.05
# 1    56.15
# Name: Gasto_mensal, dtype: float64

# %% [markdown]
# Temos que 0 25% quartil do grupo sim é próximo da mediana do grupo que não evadiu. Assim separar os grupos pelo valor do 25% do quartil irá fazer com que 25% dos evasores se torne permanecentes, e 50% dos permanecentes se tornará evasor

# %%
lista_01 = []
for item in variaveis_quanti['Gasto_mensal'].values:
  if item >= 56:
    lista_01.append(1)
  else: lista_01.append(0)
lista_01[:5]
# Out:
# [1, 1, 0, 1, 0]

# %%
df_modelo['GastoMensal01'] = lista_01
df_modelo
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
# ...      ...    ...       ...          ...            ...             ...
# 7020       1      1         0            0              1               0
# 7023       1      1         0            0              1               0
# 7036       1      0         0            0              1               0
# 7037       1      0         0            0              0               0
# 7039       1      0         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
# ...            ...               ...                     ...
# 7020             1                 0                       0
# 7023             1                 0                       0
# 7036             1                 0                       1
# 7037             1                 0                       0
# 7039             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
# ...                         ...                       ...
# 7020                          0                         0
# 7023                          1                         0
# 7036                          0                         0
# 7037                          0                         0
# 7039                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
# ...                       ...           ...                   ...
# 7020                        1             0                     1
# 7023                        0             0                     1
# 7036                        0             0                     1
# 7037                        1             0                     0
# 7039                        0             0                     1
#
#       Internet_SemInternet  Tv  Filme_sim  Meses01  GastoMensal01
# 1597                     0   1          1        0              1
# 4287                     0   1          1        0              1
# 778                      0   0          0        0              0
# 1037                     0   1          1        0              1
# 2747                     0   0          0        0              0
# ...                    ...  ..        ...      ...            ...
# 7020                     0   1          1        0              1
# 7023                     0   0          1        1              1
# 7036                     0   0          0        1              1
# 7037                     1   0          0        1              0
# 7039                     0   0          1        0              1
#
# [3759 rows x 19 columns]

# %%
x= df_modelo[['Idoso', 'Parceiro', 'Dependencia', 'Fatura_online',
       'Contrato_anual', 'Contrato_mes', 'Contrato_bianual',
       'Pagamento_Cheque_Email', 'Pagamento_Cheque_Eletrico',
       'Pagamento_Cartao_credito', 'Pagamento_Transferencia', 'Internet_DSL',
       'Internet_FibraOptica', 'Internet_SemInternet', 'Tv', 'Filme_sim',
       'Meses01','GastoMensal01']]
x.head()
# Out:
#       Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597      0         0            0              1               0
# 4287      0         0            0              1               0
# 778       0         1            0              1               0
# 1037      0         1            1              1               0
# 2747      1         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
#
#       Internet_SemInternet  Tv  Filme_sim  Meses01  GastoMensal01
# 1597                     0   1          1        0              1
# 4287                     0   1          1        0              1
# 778                      0   0          0        0              0
# 1037                     0   1          1        0              1
# 2747                     0   0          0        0              0

# %%
y = df_modelo['Evadiu']
y.head()
# Out:
# 1597    0
# 4287    0
# 778     0
# 1037    0
# 2747    0
# Name: Evadiu, dtype: int64

# %%
seed = np.random.seed = 10

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,random_state = seed, stratify = y)
print(treino_x.shape)
print(teste_x.shape)

modelo = LinearSVC()
modelo.fit(treino_x,treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y,previsoes)*100
print('A acuracia do modelo é de %.2f%%' %acuracia)

from sklearn.dummy import DummyClassifier
dummy = DummyClassifier()
dummy.fit(treino_x, treino_y)
previsoesDummy = dummy.predict(teste_x)
acuracia = accuracy_score(teste_y,previsoesDummy)*100
print('A acuracia do Dummy é de %.2f%%' %acuracia)
# Out:
# (2819, 18)
# (940, 18)
# A acuracia do modelo é de 77.13%
# A acuracia do Dummy é de 50.32%

# %% [markdown]
# ### Gasto Total

# %%
variaveis_quanti.query('Evadiu==1')['Gasto_total'].plot.box()

# %%
variaveis_quanti.query('Evadiu==0')['Gasto_total'].plot.box()

# %%
print(variaveis_quanti.groupby('Evadiu').quantile(0.6)['Gasto_total'])
print(variaveis_quanti.groupby('Evadiu').quantile(0.4)['Gasto_total'])
# Out:
# Evadiu
# 0    2560.29
# 1    1128.75
# Name: Gasto_total, dtype: float64
# Evadiu
# 0    1185.57
# 1     371.70
# Name: Gasto_total, dtype: float64

# %%
lista_01 = []
for item in variaveis_quanti['Gasto_total'].values:
  if item <= 1128:
    lista_01.append(1)
  else: lista_01.append(0)
lista_01[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
df_modelo['GastoTotal01'] = lista_01
df_modelo
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
# ...      ...    ...       ...          ...            ...             ...
# 7020       1      1         0            0              1               0
# 7023       1      1         0            0              1               0
# 7036       1      0         0            0              1               0
# 7037       1      0         0            0              0               0
# 7039       1      0         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
# ...            ...               ...                     ...
# 7020             1                 0                       0
# 7023             1                 0                       0
# 7036             1                 0                       1
# 7037             1                 0                       0
# 7039             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
# ...                         ...                       ...
# 7020                          0                         0
# 7023                          1                         0
# 7036                          0                         0
# 7037                          0                         0
# 7039                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
# ...                       ...           ...                   ...
# 7020                        1             0                     1
# 7023                        0             0                     1
# 7036                        0             0                     1
# 7037                        1             0                     0
# 7039                        0             0                     1
#
#       Internet_SemInternet  Tv  Filme_sim  Meses01  GastoMensal01  \
# 1597                     0   1          1        0              1
# 4287                     0   1          1        0              1
# 778                      0   0          0        0              0
# 1037                     0   1          1        0              1
# 2747                     0   0          0        0              0
# ...                    ...  ..        ...      ...            ...
# 7020                     0   1          1        0              1
# 7023                     0   0          1        1              1
# 7036                     0   0          0        1              1
# 7037                     1   0          0        1              0
# 7039                     0   0          1        0              1
#
#       GastoTotal01
# 1597             0
# 4287             0
# 778              0
# 1037             0
# 2747             0
# ...            ...
# 7020             0
# 7023             1
# 7036             1
# 7037             1
# 7039             0
#
# [3759 rows x 20 columns]

# %%
x= df_modelo[['Idoso', 'Parceiro', 'Dependencia', 'Fatura_online',
       'Contrato_anual', 'Contrato_mes', 'Contrato_bianual',
       'Pagamento_Cheque_Email', 'Pagamento_Cheque_Eletrico',
       'Pagamento_Cartao_credito', 'Pagamento_Transferencia', 'Internet_DSL',
       'Internet_FibraOptica', 'Internet_SemInternet', 'Tv', 'Filme_sim',
       'Meses01','GastoMensal01','GastoTotal01']]
y = df_modelo['Evadiu']

# %%
seed = np.random.seed = 10

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,random_state = seed, stratify = y)
print(treino_x.shape)
print(teste_x.shape)

modelo = LinearSVC()
modelo.fit(treino_x,treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y,previsoes)*100
print('A acuracia do modelo é de %.2f%%' %acuracia)

from sklearn.dummy import DummyClassifier
dummy = DummyClassifier()
dummy.fit(treino_x, treino_y)
previsoesDummy = dummy.predict(teste_x)
acuracia = accuracy_score(teste_y,previsoesDummy)*100
print('A acuracia do Dummy é de %.2f%%' %acuracia)
# Out:
# (2819, 19)
# (940, 19)
# A acuracia do modelo é de 77.66%
# A acuracia do Dummy é de 50.32%

# %% [markdown]
# ### Gastos Diários

# %% [markdown]
# A variável Gasto Diário foi feita com base no gasto mensal, e na análise descritiva tivemos uma informação de que o gasto diários dos evasores era de 2.5 e dos permanecentes de 2.0.
#
# Vamos usar essa informação e a metade da diferença (2.25) para definir quem evadiu e quem não evadiu

# %%
lista_01 = []
for item in variaveis_quanti['Gasto_diario'].values:
  if item >= 2.25:
    lista_01.append(1)
  else: lista_01.append(0)
df_modelo['GastoDiario01'] = lista_01
df_modelo
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
# ...      ...    ...       ...          ...            ...             ...
# 7020       1      1         0            0              1               0
# 7023       1      1         0            0              1               0
# 7036       1      0         0            0              1               0
# 7037       1      0         0            0              0               0
# 7039       1      0         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
# ...            ...               ...                     ...
# 7020             1                 0                       0
# 7023             1                 0                       0
# 7036             1                 0                       1
# 7037             1                 0                       0
# 7039             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  ...  Pagamento_Transferencia  Internet_DSL  \
# 1597                          0  ...                        1             0
# 4287                          0  ...                        1             0
# 778                           1  ...                        0             1
# 1037                          1  ...                        0             1
# 2747                          1  ...                        0             1
# ...                         ...  ...                      ...           ...
# 7020                          0  ...                        1             0
# 7023                          1  ...                        0             0
# 7036                          0  ...                        0             0
# 7037                          0  ...                        1             0
# 7039                          1  ...                        0             0
#
#       Internet_FibraOptica  Internet_SemInternet  Tv  Filme_sim  Meses01  \
# 1597                     1                     0   1          1        0
# 4287                     1                     0   1          1        0
# 778                      0                     0   0          0        0
# 1037                     0                     0   1          1        0
# 2747                     0                     0   0          0        0
# ...                    ...                   ...  ..        ...      ...
# 7020                     1                     0   1          1        0
# 7023                     1                     0   0          1        1
# 7036                     1                     0   0          0        1
# 7037                     0                     1   0          0        1
# 7039                     1                     0   0          1        0
#
#       GastoMensal01  GastoTotal01  GastoDiario01
# 1597              1             0              1
# 4287              1             0              1
# 778               0             0              0
# 1037              1             0              1
# 2747              0             0              0
# ...             ...           ...            ...
# 7020              1             0              1
# 7023              1             1              1
# 7036              1             1              1
# 7037              0             1              0
# 7039              1             0              1
#
# [3759 rows x 21 columns]

# %%
x= df_modelo[['Idoso', 'Parceiro', 'Dependencia', 'Fatura_online',
       'Contrato_anual', 'Contrato_mes', 'Contrato_bianual',
       'Pagamento_Cheque_Email', 'Pagamento_Cheque_Eletrico',
       'Pagamento_Cartao_credito', 'Pagamento_Transferencia', 'Internet_DSL',
       'Internet_FibraOptica', 'Internet_SemInternet', 'Tv', 'Filme_sim',
       'Meses01','GastoMensal01','GastoTotal01','GastoDiario01']]
y = df_modelo['Evadiu']

# %%
seed = np.random.seed = 10

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,random_state = seed, stratify = y)
print(treino_x.shape)
print(teste_x.shape)

modelo = LinearSVC()
modelo.fit(treino_x,treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y,previsoes)*100
print('A acuracia do modelo é de %.2f%%' %acuracia)

from sklearn.dummy import DummyClassifier
dummy = DummyClassifier()
dummy.fit(treino_x, treino_y)
previsoesDummy = dummy.predict(teste_x)
acuracia = accuracy_score(teste_y,previsoesDummy)*100
print('A acuracia do Dummy é de %.2f%%' %acuracia)
# Out:
# (2819, 20)
# (940, 20)
# A acuracia do modelo é de 77.77%
# A acuracia do Dummy é de 50.32%

# %% [markdown]
# ### Vamos salvar os dados prontos para este Modelo

# %%
df_modelo.to_csv('Dados_Para_Modelo_Classificacao.csv',index = False)

# %% [markdown]
# ## 3º Modelo: Árvore de Decisão

# %%
variaveis_cat
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
# ...      ...    ...       ...          ...            ...             ...
# 7020       1      1         0            0              1               0
# 7023       1      1         0            0              1               0
# 7036       1      0         0            0              1               0
# 7037       1      0         0            0              0               0
# 7039       1      0         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
# ...            ...               ...                     ...
# 7020             1                 0                       0
# 7023             1                 0                       0
# 7036             1                 0                       1
# 7037             1                 0                       0
# 7039             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
# 778                           1                         0
# 1037                          1                         0
# 2747                          1                         0
# ...                         ...                       ...
# 7020                          0                         0
# 7023                          1                         0
# 7036                          0                         0
# 7037                          0                         0
# 7039                          1                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
# 778                         0             1                     0
# 1037                        0             1                     0
# 2747                        0             1                     0
# ...                       ...           ...                   ...
# 7020                        1             0                     1
# 7023                        0             0                     1
# 7036                        0             0                     1
# 7037                        1             0                     0
# 7039                        0             0                     1
#
#       Internet_SemInternet  Tv  Filme_sim
# 1597                     0   1          1
# 4287                     0   1          1
# 778                      0   0          0
# 1037                     0   1          1
# 2747                     0   0          0
# ...                    ...  ..        ...
# 7020                     0   1          1
# 7023                     0   0          1
# 7036                     0   0          0
# 7037                     1   0          0
# 7039                     0   0          1
#
# [3759 rows x 17 columns]

# %%
variaveis_quanti.head()
# Out:
#       Gasto_total  Gasto_mensal  Gasto_diario  Meses_de_contrato  Evadiu  \
# 1597      6692.65        104.40      3.480000                 64       0
# 4287      5129.45         97.20      3.240000                 54       0
# 778       1389.85         53.80      1.793333                 27       0
# 1037      5186.00         86.75      2.891667                 59       0
# 2747      2965.75         41.95      1.398333                 68       0
#
#       Meses01
# 1597        0
# 4287        0
# 778         0
# 1037        0
# 2747        0

# %%
df_arvore = pd.concat([variaveis_cat,variaveis_quanti.drop(['Meses01','Evadiu'],axis = 1)], axis = 1)
df_arvore
# Out:
#       Evadiu  Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597       0      0         0            0              1               0
# 4287       0      0         0            0              1               0
# 778        0      0         1            0              1               0
# 1037       0      0         1            1              1               0
# 2747       0      1         1            0              1               0
# ...      ...    ...       ...          ...            ...             ...
# 7020       1      1         0            0              1               0
# 7023       1      1         0            0              1               0
# 7036       1      0         0            0              1               0
# 7037       1      0         0            0              0               0
# 7039       1      0         1            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
# 778              1                 0                       0
# 1037             0                 1                       0
# 2747             0                 1                       0
# ...            ...               ...                     ...
# 7020             1                 0                       0
# 7023             1                 0                       0
# 7036             1                 0                       1
# 7037             1                 0                       0
# 7039             1                 0                       0
#
#       Pagamento_Cheque_Eletrico  ...  Pagamento_Transferencia  Internet_DSL  \
# 1597                          0  ...                        1             0
# 4287                          0  ...                        1             0
# 778                           1  ...                        0             1
# 1037                          1  ...                        0             1
# 2747                          1  ...                        0             1
# ...                         ...  ...                      ...           ...
# 7020                          0  ...                        1             0
# 7023                          1  ...                        0             0
# 7036                          0  ...                        0             0
# 7037                          0  ...                        1             0
# 7039                          1  ...                        0             0
#
#       Internet_FibraOptica  Internet_SemInternet  Tv  Filme_sim  Gasto_total  \
# 1597                     1                     0   1          1      6692.65
# 4287                     1                     0   1          1      5129.45
# 778                      0                     0   0          0      1389.85
# 1037                     0                     0   1          1      5186.00
# 2747                     0                     0   0          0      2965.75
# ...                    ...                   ...  ..        ...          ...
# 7020                     1                     0   1          1      2030.30
# 7023                     1                     0   0          1       790.15
# 7036                     1                     0   0          0        70.15
# 7037                     0                     1   0          0        85.50
# 7039                     1                     0   0          1      1873.70
#
#       Gasto_mensal  Gasto_diario  Meses_de_contrato
# 1597        104.40      3.480000                 64
# 4287         97.20      3.240000                 54
# 778          53.80      1.793333                 27
# 1037         86.75      2.891667                 59
# 2747         41.95      1.398333                 68
# ...            ...           ...                ...
# 7020         96.80      3.226667                 21
# 7023         83.85      2.795000                  9
# 7036         70.15      2.338333                  1
# 7037         20.95      0.698333                  4
# 7039         85.10      2.836667                 22
#
# [3759 rows x 21 columns]

# %%
x = df_arvore.drop(['Evadiu'], axis = 1)
x.head(2)
# Out:
#       Idoso  Parceiro  Dependencia  Fatura_online  Contrato_anual  \
# 1597      0         0            0              1               0
# 4287      0         0            0              1               0
#
#       Contrato_mes  Contrato_bianual  Pagamento_Cheque_Email  \
# 1597             0                 1                       0
# 4287             0                 1                       0
#
#       Pagamento_Cheque_Eletrico  Pagamento_Cartao_credito  \
# 1597                          0                         0
# 4287                          0                         0
#
#       Pagamento_Transferencia  Internet_DSL  Internet_FibraOptica  \
# 1597                        1             0                     1
# 4287                        1             0                     1
#
#       Internet_SemInternet  Tv  Filme_sim  Gasto_total  Gasto_mensal  \
# 1597                     0   1          1      6692.65         104.4
# 4287                     0   1          1      5129.45          97.2
#
#       Gasto_diario  Meses_de_contrato
# 1597          3.48                 64
# 4287          3.24                 54

# %%
y = df_arvore['Evadiu']
y.head(2)
# Out:
# 1597    0
# 4287    0
# Name: Evadiu, dtype: int64

# %%
from sklearn import tree

seed = np.random.seed = 10
x_treino, x_teste, y_treino, y_teste =  train_test_split(x, y, test_size = 0.25,random_state = seed, stratify = y)

# %%
modelo_arvore = tree.DecisionTreeClassifier(max_depth = 5)
arvore = modelo_arvore.fit(x_treino,y_treino)
y_pred = arvore.predict(x_teste)
acuracia = accuracy_score(y_teste,y_pred)*100
print('A acuracia do modelo é de %.2f%%' %acuracia)
# Out:
# A acuracia do modelo é de 75.53%

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (200,100))
tree.plot_tree(modelo_arvore, filled = True, fontsize = 14)
plt.savefig('DecisionTree_5N.png')
plt.close()

# %% [markdown]
# ## Escolha do Modelo
# * O modelo Dummy usado como base para aceitar nosso modelo teve uma taxa de acerto de 50.25%.
# * O modelo baseado no LinearSVC com criação de grupos das variáveis quantitativas obteve uma taxa de acerto de 77.77%.
# * O modelo baseado no DecisionTreeClassification teve uma taxa de acerto igual a 75.53%.
#
# <font color ='Darkblue'><b>Com base nesses dados devemos escolher como melhor modelo o baseado no LinearSVC</b></font>
